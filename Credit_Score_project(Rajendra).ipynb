# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("C:\\Users\\Shree Com\\Desktop\\Data\\credit_score.csv")

# %%
df
# Out:
#            ID  Customer_ID  Month           Name   Age          SSN  \
# 0        5634         3392      1  Aaron Maashoh  23.0  821000265.0
# 1        5635         3392      2  Aaron Maashoh  23.0  821000265.0
# 2        5636         3392      3  Aaron Maashoh  23.0  821000265.0
# 3        5637         3392      4  Aaron Maashoh  23.0  821000265.0
# 4        5638         3392      5  Aaron Maashoh  23.0  821000265.0
# ...       ...          ...    ...            ...   ...          ...
# 99995  155625        37932      4          Nicks  25.0   78735990.0
# 99996  155626        37932      5          Nicks  25.0   78735990.0
# 99997  155627        37932      6          Nicks  25.0   78735990.0
# 99998  155628        37932      7          Nicks  25.0   78735990.0
# 99999  155629        37932      8          Nicks  25.0   78735990.0
#
#       Occupation  Annual_Income  Monthly_Inhand_Salary  Num_Bank_Accounts  \
# 0      Scientist       19114.12            1824.843333                3.0
# ...

# %%
df=df.drop(columns=["Name","SSN"])

# %%
df.isnull().sum()
# Out:
# ID                          0
# Customer_ID                 0
# Month                       0
# Age                         0
# Occupation                  0
# Annual_Income               0
# Monthly_Inhand_Salary       0
# Num_Bank_Accounts           0
# Num_Credit_Card             0
# Interest_Rate               0
# Num_of_Loan                 0
# Type_of_Loan                0
# Delay_from_due_date         0
# Num_of_Delayed_Payment      0
# Changed_Credit_Limit        0
# Num_Credit_Inquiries        0
# Credit_Mix                  0
# Outstanding_Debt            0
# Credit_Utilization_Ratio    0
# Credit_History_Age          0
# Payment_of_Min_Amount       0
# Total_EMI_per_month         0
# Amount_invested_monthly     0
# Payment_Behaviour           0
# Monthly_Balance             0
# Credit_Score                0
# dtype: int64

# %%
pd.crosstab(df["Occupation"],df["Credit_Score"])
# Out:
# Credit_Score   Good  Poor  Standard
# Occupation
# Accountant     1205  2037      3502
# Architect      1233  1855      3736
# Developer      1210  1924      3586
# Doctor         1164  1804      3600
# Engineer       1264  2094      3506
# Entrepreneur   1185  2033      3430
# Journalist     1254  1840      3442
# Lawyer         1259  1965      3872
# Manager        1190  1856      3386
# Mechanic       1107  2044      3625
# Media_Manager  1244  1764      3712
# Musician       1192  1786      3374
# Scientist      1201  2062      3481
# Teacher        1224  2027      3421
# Writer          896  1907      3501

# %%
plt.figure(figsize=(16,10)) 

plt=sns.countplot(df["Occupation"],hue=df["Credit_Score"])
print(plt)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# AxesSubplot(0.125,0.11;0.775x0.77)

# %%
df.head(2)
# Out:
#      ID  Customer_ID  Month   Age Occupation  Annual_Income  \
# 0  5634         3392      1  23.0  Scientist       19114.12
# 1  5635         3392      2  23.0  Scientist       19114.12
#
#    Monthly_Inhand_Salary  Num_Bank_Accounts  Num_Credit_Card  Interest_Rate  \
# 0            1824.843333                3.0              4.0            3.0
# 1            1824.843333                3.0              4.0            3.0
#
#    ...  Credit_Mix Outstanding_Debt  Credit_Utilization_Ratio  \
# 0  ...        Good           809.98                  26.82262
# 1  ...        Good           809.98                  31.94496
#
#    Credit_History_Age  Payment_of_Min_Amount  Total_EMI_per_month  \
# 0               265.0                     No            49.574949
# 1               266.0                     No            49.574949
#
#   Amount_invested_monthly                Payment_Behaviour  Monthly_Balance  \
# 0                21.46538  High_spent_Small_value_payments       312.494089
# ...

# %%
pd.crosstab(df["Num_Bank_Accounts"],df["Credit_Score"])
# Out:
# Credit_Score       Good  Poor  Standard
# Num_Bank_Accounts
# 0.0                1952   788      1677
# 1.0                2088   713      1739
# 2.0                2148   641      1551
# 3.0                2989  1892      7226
# 4.0                3014  1949      7380
# 5.0                2899  2003      7396
# 6.0                 947  4725      7503
# 7.0                 792  4851      7356
# 8.0                 860  4714      7366
# 9.0                  65  3465      1973
# 10.0                 74  3251      2004
# 11.0                  0     6         3

# %%
pd.crosstab(df["Num_Credit_Card"],df["Credit_Score"])
# Out:
# Credit_Score     Good  Poor  Standard
# Num_Credit_Card
# 0.0                11     0         3
# 1.0              1703     2       480
# 2.0              1690    14       492
# 3.0              3228  1882      8450
# 4.0              3497  2017      8848
# 5.0              3598  5335      9970
# 6.0              1917  5132      9883
# 7.0              1991  5310      9723
# 8.0                92  3187      1794
# 9.0                64  2973      1716
# 10.0               37  3124      1801
# 11.0                0    22        14

# %%
pd.crosstab(df["Interest_Rate"],df["Credit_Score"])
# Out:
# Credit_Score   Good  Poor  Standard
# Interest_Rate
# 1.0            1241   411      1092
# 2.0            1227   390       903
# 3.0            1317   444      1063
# 4.0            1415   367       858
# 5.0            1466   666      2964
# 6.0            1307   519      3006
# 7.0            1354   584      2646
# 8.0            1539   717      2848
# 9.0            1241   584      2751
# 10.0           1184   612      2820
# 11.0           1378   581      2553
# 12.0           1455   443      2750
# 13.0            169   136      2127
# 14.0            135   185      1952
# 15.0            238  1186      2648
# 16.0            221  1261      2318
# 17.0            151  1220      2517
# 18.0            179  1402      2611
# 19.0            185  1188      2331
# 20.0            182  1221      2605
# 21.0             21  1032       539
# 22.0             16  1209       527
# 23.0             31  1170       519
# 24.0             26  1197       513
# ...

# %%
df.columns
# Out:
# Index(['ID', 'Customer_ID', 'Month', 'Age', 'Occupation', 'Annual_Income',
#        'Monthly_Inhand_Salary', 'Num_Bank_Accounts', 'Num_Credit_Card',
#        'Interest_Rate', 'Num_of_Loan', 'Type_of_Loan', 'Delay_from_due_date',
#        'Num_of_Delayed_Payment', 'Changed_Credit_Limit',
#        'Num_Credit_Inquiries', 'Credit_Mix', 'Outstanding_Debt',
#        'Credit_Utilization_Ratio', 'Credit_History_Age',
#        'Payment_of_Min_Amount', 'Total_EMI_per_month',
#        'Amount_invested_monthly', 'Payment_Behaviour', 'Monthly_Balance',
#        'Credit_Score'],
#       dtype='object')

# %%
pd.crosstab(df["Payment_Behaviour"],df["Credit_Score"])
# Out:
# Credit_Score                      Good   Poor  Standard
# Payment_Behaviour
# High_spent_Large_value_payments   3445   3164      8117
# High_spent_Medium_value_payments  3954   5073     10711
# High_spent_Small_value_payments   2187   3215      6362
# Low_spent_Large_value_payments    1939   3027      5791
# Low_spent_Medium_value_payments   2598   4344      7457
# Low_spent_Small_value_payments    3705  10175     14736

# %%
pd.crosstab(df["Month"],df["Credit_Score"])
# Out:
# Credit_Score  Good  Poor  Standard
# Month
# 1             1975  3582      6943
# 2             2016  3539      6945
# 3             1984  3551      6965
# 4             2357  3670      6473
# 5             2310  3712      6478
# 6             2362  3728      6410
# 7             2411  3614      6475
# 8             2413  3602      6485

# %%
pd.crosstab(df["Num_of_Loan"],df["Credit_Score"])
# Out:
# Credit_Score  Good  Poor  Standard
# Num_of_Loan
# 0.0           3444  1336      6628
# 1.0           3170  1233      6725
# 2.0           3441  3757      8514
# 3.0           3602  3437      8713
# 4.0           3473  3284      8699
# 5.0            194  3891      3443
# 6.0            189  4132      3823
# 7.0            183  4025      3472
# 8.0             63  1836      1437
# 9.0             69  2067      1720

# %%
df1=df.copy()

# %%
df1.columns
# Out:
# Index(['ID', 'Customer_ID', 'Month', 'Age', 'Occupation', 'Annual_Income',
#        'Monthly_Inhand_Salary', 'Num_Bank_Accounts', 'Num_Credit_Card',
#        'Interest_Rate', 'Num_of_Loan', 'Type_of_Loan', 'Delay_from_due_date',
#        'Num_of_Delayed_Payment', 'Changed_Credit_Limit',
#        'Num_Credit_Inquiries', 'Credit_Mix', 'Outstanding_Debt',
#        'Credit_Utilization_Ratio', 'Credit_History_Age',
#        'Payment_of_Min_Amount', 'Total_EMI_per_month',
#        'Amount_invested_monthly', 'Payment_Behaviour', 'Monthly_Balance',
#        'Credit_Score'],
#       dtype='object')

# %%
df1=df1.drop(columns=["ID","Num_Credit_Inquiries","Credit_Mix","Payment_of_Min_Amount"])

# %%
df1=df1.drop(columns=["Customer_ID","Month","Payment_Behaviour","Type_of_Loan"])

# %%
df1.columns
# Out:
# Index(['Age', 'Occupation', 'Annual_Income', 'Monthly_Inhand_Salary',
#        'Num_Bank_Accounts', 'Num_Credit_Card', 'Interest_Rate', 'Num_of_Loan',
#        'Delay_from_due_date', 'Num_of_Delayed_Payment', 'Changed_Credit_Limit',
#        'Outstanding_Debt', 'Credit_Utilization_Ratio', 'Credit_History_Age',
#        'Total_EMI_per_month', 'Amount_invested_monthly', 'Monthly_Balance',
#        'Credit_Score'],
#       dtype='object')

# %%
df1
# Out:
#         Age Occupation  Annual_Income  Monthly_Inhand_Salary  \
# 0      23.0  Scientist       19114.12            1824.843333
# 1      23.0  Scientist       19114.12            1824.843333
# 2      23.0  Scientist       19114.12            1824.843333
# 3      23.0  Scientist       19114.12            1824.843333
# 4      23.0  Scientist       19114.12            1824.843333
# ...     ...        ...            ...                    ...
# 99995  25.0   Mechanic       39628.99            3359.415833
# 99996  25.0   Mechanic       39628.99            3359.415833
# 99997  25.0   Mechanic       39628.99            3359.415833
# 99998  25.0   Mechanic       39628.99            3359.415833
# 99999  25.0   Mechanic       39628.99            3359.415833
#
#        Num_Bank_Accounts  Num_Credit_Card  Interest_Rate  Num_of_Loan  \
# 0                    3.0              4.0            3.0          4.0
# 1                    3.0              4.0            3.0          4.0
# ...

# %%
df2=df1.copy()
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
new2=le.fit_transform(df2[["Occupation"]])
data=pd.DataFrame(new2,columns=["Occupation"])
df2["Occupation"]=data
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\_label.py:115: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
df
# Out:
#            ID  Customer_ID  Month   Age Occupation  Annual_Income  \
# 0        5634         3392      1  23.0  Scientist       19114.12
# 1        5635         3392      2  23.0  Scientist       19114.12
# 2        5636         3392      3  23.0  Scientist       19114.12
# 3        5637         3392      4  23.0  Scientist       19114.12
# 4        5638         3392      5  23.0  Scientist       19114.12
# ...       ...          ...    ...   ...        ...            ...
# 99995  155625        37932      4  25.0   Mechanic       39628.99
# 99996  155626        37932      5  25.0   Mechanic       39628.99
# 99997  155627        37932      6  25.0   Mechanic       39628.99
# 99998  155628        37932      7  25.0   Mechanic       39628.99
# 99999  155629        37932      8  25.0   Mechanic       39628.99
#
#        Monthly_Inhand_Salary  Num_Bank_Accounts  Num_Credit_Card  \
# 0                1824.843333                3.0              4.0
# ...

# %%
df2["Age"]=df2["Age"].astype(int)
df2["Num_Bank_Accounts"]=df2["Num_Bank_Accounts"].astype(int)
df2["Num_Credit_Card"]=df2["Num_Credit_Card"].astype(int)
df2["Interest_Rate"]=df2["Interest_Rate"].astype(int)
df2["Num_of_Loan"]=df2["Num_of_Loan"].astype(int)
df2["Delay_from_due_date"]=df2["Delay_from_due_date"].astype(int)
df2["Num_of_Delayed_Payment"]=df2["Num_of_Delayed_Payment"].astype(int)



df2
# Out:
#        Age  Occupation  Annual_Income  Monthly_Inhand_Salary  \
# 0       23          12       19114.12            1824.843333
# 1       23          12       19114.12            1824.843333
# 2       23          12       19114.12            1824.843333
# 3       23          12       19114.12            1824.843333
# 4       23          12       19114.12            1824.843333
# ...    ...         ...            ...                    ...
# 99995   25           9       39628.99            3359.415833
# 99996   25           9       39628.99            3359.415833
# 99997   25           9       39628.99            3359.415833
# 99998   25           9       39628.99            3359.415833
# 99999   25           9       39628.99            3359.415833
#
#        Num_Bank_Accounts  Num_Credit_Card  Interest_Rate  Num_of_Loan  \
# 0                      3                4              3            4
# 1                      3                4              3            4
# ...

# %%
x=df2.iloc[:,:-1]

y=df2.iloc[:,-1]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=33)

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rfr=RandomForestClassifier(n_estimators=100)

# %%
rfr.fit(x_train,y_train)
# Out:
# RandomForestClassifier()

# %%
rfr.score(x_test,y_test)
# Out:
# 0.8133

# %%
a=x_train.iloc[5,:]
b=np.array([a])

# %%
rfr.predict(b)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# array(['Good'], dtype=object)

# %%
x_train.columns
# Out:
# Index(['Age', 'Occupation', 'Annual_Income', 'Monthly_Inhand_Salary',
#        'Num_Bank_Accounts', 'Num_Credit_Card', 'Interest_Rate', 'Num_of_Loan',
#        'Delay_from_due_date', 'Num_of_Delayed_Payment', 'Changed_Credit_Limit',
#        'Outstanding_Debt', 'Credit_Utilization_Ratio', 'Credit_History_Age',
#        'Total_EMI_per_month', 'Amount_invested_monthly', 'Monthly_Balance'],
#       dtype='object')

# %%
index=df2[["Occupation"]]
index["Occupation_new"]=df["Occupation"]
index.value_counts()
# Out:
# C:\Users\Shree Com\AppData\Local\Temp\ipykernel_1924\2266913685.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   index["Occupation_new"]=df["Occupation"]
# Occupation  Occupation_new
# 7           Lawyer            7096
# 4           Engineer          6864
# 1           Architect         6824
# 9           Mechanic          6776
# 0           Accountant        6744
# 12          Scientist         6744
# 2           Developer         6720
# 10          Media_Manager     6720
# 13          Teacher           6672
# 5           Entrepreneur      6648
# 3           Doctor            6568
# 6           Journalist        6536
# 8           Manager           6432
# 11          Musician          6352
# 14          Writer            6304
# ...

# %%
Age=int(input("Please Enter Your Age : "))
Occupation=int(input("enter Occupetion : "))
Annual_Income=int(input("enter annual income :"))
Monthly_Inhand_Salary=int(input("enter monthly Monthly_Inhand_Salary :"))
Num_Bank_Accounts=int(input("enter bank Account:"))
Num_Credit_Card = int(input("enter credit card :"))
Interest_Rate= int(input(" enter interest Rate :"))
Num_of_Loan=int(input("enter number of loan :"))
Delay_from_due_date=int(input("enter due date : "))
Num_of_Delayed_Payment=int(input("enter Num_of_Delayed_Payment : "))
Changed_Credit_Limit=int(input("enter Change credit limit :"))
Outstanding_Debt=int(input("enter Outstanding_dept : "))
Credit_Utilization_Ratio=int(input("enter Credit_Utilization_Ratio : "))
Credit_History_Age=int(input("enter Credit_History_Age :"))
Total_EMI_per_month=int(input("Enter Total_EMI_per_month : "))
Amount_invested_monthly=int(input("Enter Amount_invested_monthly : "))
Monthly_Balance=int(input("Enter Monthly_Balance :"))
# Out:
# Please Enter Your Age : 30
# enter Occupetion : 2
# enter annual income :20000
# enter monthly Monthly_Inhand_Salary :2000
# enter bank Account:5
# enter credit card :2
#  enter interest Rate :3
# enter number of loan :2
# enter due date : 1
# enter Num_of_Delayed_Payment : 3
# enter Change credit limit :11
# enter Outstanding_dept : 21
# enter Credit_Utilization_Ratio : 30
# enter Credit_History_Age :200
# Enter Total_EMI_per_month : 50
# Enter Amount_invested_monthly : 300
# Enter Monthly_Balance :330

# %%
mylist=[Age,Occupation,Annual_Income,Monthly_Inhand_Salary,Num_Bank_Accounts,Num_Credit_Card,Interest_Rate,Num_of_Loan,Delay_from_due_date,Num_of_Delayed_Payment,Changed_Credit_Limit,Outstanding_Debt,Credit_Utilization_Ratio,Credit_History_Age,Total_EMI_per_month,Amount_invested_monthly,Monthly_Balance]

# %%
feature=np.array([mylist])
feature.ndim
# Out:
# 2

# %%
rfr.predict(feature)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# array(['Good'], dtype=object)

# %%
# df2.columns
