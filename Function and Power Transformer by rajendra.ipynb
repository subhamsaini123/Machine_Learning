# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv("C:\\Users\\subha\\OneDrive\\Documents\\titanic.py.csv",usecols=["Age","Fare"])

# %%
df
# Out:
#       Age      Fare
# 0    34.5    7.8292
# 1    47.0    7.0000
# 2    62.0    9.6875
# 3    27.0    8.6625
# 4    22.0   12.2875
# ..    ...       ...
# 413   NaN    8.0500
# 414  39.0  108.9000
# 415  38.5    7.2500
# 416   NaN    8.0500
# 417   NaN   22.3583
#
# [418 rows x 2 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=df[["Fare"]]

# %%
sns.distplot(df["Fare"])
# Out:
# C:\Users\subha\AppData\Local\Temp\ipykernel_16548\1092105540.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["Fare"])
# <AxesSubplot: xlabel='Fare', ylabel='Density'>

# %%
df.skew()
# Out:
# Fare    3.687213
# dtype: float64

# %%
from sklearn.preprocessing import PowerTransformer

# %%
pt=PowerTransformer(method="yeo-johnson")

# %%
a=pt.fit_transform(df+0.001)

# %%
sns.distplot(a)
# Out:
# C:\Users\subha\AppData\Local\Temp\ipykernel_16548\819221729.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(a)
# <AxesSubplot: ylabel='Density'>

# %%
pt=PowerTransformer(method="box-cox")

# %%
b=pt.fit_transform(df+0.001)

# %%
# df_new=pd.DataFrame(b,columns=["new"])
# df_new.skew()

# %%
sns.distplot(b)
# Out:
# C:\Users\subha\AppData\Local\Temp\ipykernel_16548\1062453464.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(b)
# <AxesSubplot: ylabel='Density'>

# %%
df=pd.read_csv("C:\\Users\\subha\\OneDrive\\Documents\\titanic.py.csv")

# %%
df=df["Age"]

# %%
df
# Out:
# 0      34.5
# 1      47.0
# 2      62.0
# 3      27.0
# 4      22.0
#        ...
# 413     NaN
# 414    39.0
# 415    38.5
# 416     NaN
# 417     NaN
# Name: Age, Length: 418, dtype: float64

# %%
def add(x):
    return x-2

# %%
from sklearn.preprocessing import FunctionTransformer

# %%
ft=FunctionTransformer(func=add)

# %%
a=ft.transform(df)

# %%
df
# Out:
# 0      34.5
# 1      47.0
# 2      62.0
# 3      27.0
# 4      22.0
#        ...
# 413     NaN
# 414    39.0
# 415    38.5
# 416     NaN
# 417     NaN
# Name: Age, Length: 418, dtype: float64

# %%
a
# Out:
# 0      32.5
# 1      45.0
# 2      60.0
# 3      25.0
# 4      20.0
#        ...
# 413     NaN
# 414    37.0
# 415    36.5
# 416     NaN
# 417     NaN
# Name: Age, Length: 418, dtype: float64

# %%
def nun(x):
    x[np.isnan(x)]=0
    return x

# %%
ft=FunctionTransformer(func=nun)

# %%
ft.transform(df)
# Out:
# 0      34.5
# 1      47.0
# 2      62.0
# 3      27.0
# 4      22.0
#        ...
# 413     0.0
# 414    39.0
# 415    38.5
# 416     0.0
# 417     0.0
# Name: Age, Length: 418, dtype: float64
