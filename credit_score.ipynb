# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("C:\\Users\\subha\\OneDrive\\Documents\\Credit-Score-Data\\Credit Score Data\\train.csv")
df.head()
# Out:
#      ID  Customer_ID  Month           Name   Age          SSN Occupation  \
# 0  5634         3392      1  Aaron Maashoh  23.0  821000265.0  Scientist
# 1  5635         3392      2  Aaron Maashoh  23.0  821000265.0  Scientist
# 2  5636         3392      3  Aaron Maashoh  23.0  821000265.0  Scientist
# 3  5637         3392      4  Aaron Maashoh  23.0  821000265.0  Scientist
# 4  5638         3392      5  Aaron Maashoh  23.0  821000265.0  Scientist
#
#    Annual_Income  Monthly_Inhand_Salary  Num_Bank_Accounts  ...  Credit_Mix  \
# 0       19114.12            1824.843333                3.0  ...        Good
# 1       19114.12            1824.843333                3.0  ...        Good
# 2       19114.12            1824.843333                3.0  ...        Good
# 3       19114.12            1824.843333                3.0  ...        Good
# 4       19114.12            1824.843333                3.0  ...        Good
#
#    Outstanding_Debt  Credit_Utilization_Ratio Credit_History_Age  \
# ...

# %%
# df.to_string()

# %%
df["Occupation"].value_counts()
# Out:
# Lawyer           7096
# Engineer         6864
# Architect        6824
# Mechanic         6776
# Scientist        6744
# Accountant       6744
# Developer        6720
# Media_Manager    6720
# Teacher          6672
# Entrepreneur     6648
# Doctor           6568
# Journalist       6536
# Manager          6432
# Musician         6352
# Writer           6304
# Name: Occupation, dtype: int64

# %%
df["Credit_Score"].value_counts()
# Out:
# Standard    53174
# Poor        28998
# Good        17828
# Name: Credit_Score, dtype: int64

# %% [markdown]
# # Q1==>credit_score based on occupation

# %%
a=pd.crosstab([df.Occupation],[df.Credit_Score],margins=True)
a
# Out:
# Credit_Score    Good   Poor  Standard     All
# Occupation
# Accountant      1205   2037      3502    6744
# Architect       1233   1855      3736    6824
# Developer       1210   1924      3586    6720
# Doctor          1164   1804      3600    6568
# Engineer        1264   2094      3506    6864
# Entrepreneur    1185   2033      3430    6648
# Journalist      1254   1840      3442    6536
# Lawyer          1259   1965      3872    7096
# Manager         1190   1856      3386    6432
# Mechanic        1107   2044      3625    6776
# Media_Manager   1244   1764      3712    6720
# Musician        1192   1786      3374    6352
# Scientist       1201   2062      3481    6744
# Teacher         1224   2027      3421    6672
# Writer           896   1907      3501    6304
# All            17828  28998     53174  100000

# %%
plt.figure(figsize=(16,10))
sns.countplot(x=df["Occupation"],hue=df["Credit_Score"])
# Out:
# <AxesSubplot: xlabel='Occupation', ylabel='count'>

# %% [markdown]
# # Q2===>credit score based on annual income

# %%
a=pd.crosstab([df.Annual_Income],[df.Credit_Score],margins=True)
a
# Out:
# Credit_Score    Good   Poor  Standard     All
# Annual_Income
# 7005.93            0      8         0       8
# 7006.035           0      7         1       8
# 7006.52            0      6         2       8
# 7011.685           0      7         1       8
# 7012.31            0      5         3       8
# ...              ...    ...       ...     ...
# 179317.04          4      0         4       8
# 179825.36          2      0         6       8
# 179948.84          0      7         1       8
# 179987.28          0      7         1       8
# All            17828  28998     53174  100000
#
# [12489 rows x 4 columns]

# %% [markdown]
# # Q3==>credit_score based on Inhand-salary

# %%
a=pd.crosstab([df.Monthly_Inhand_Salary],[df.Credit_Score],margins=True)
a
# Out:
# Credit_Score            Good   Poor  Standard     All
# Monthly_Inhand_Salary
# 303.6454166666666          0      0         8       8
# 319.55625                  0      7         1       8
# 332.12833333333333         5      0         3       8
# 332.43125                  0      6         2       8
# 333.5966666666667          0      4         4       8
# ...                      ...    ...       ...     ...
# 15115.19                   0      8         0       8
# 15136.696666666665         7      0         1       8
# 15167.18                   0      2         6       8
# 15204.633333333331         3      0         5       8
# All                    17828  28998     53174  100000
#
# [13242 rows x 4 columns]

# %% [markdown]
# # Q4==>credit_score based on Num_Bank_Accounts

# %%
a=pd.crosstab([df.Num_Bank_Accounts],[df.Credit_Score],margins=True)
a
# Out:
# Credit_Score        Good   Poor  Standard     All
# Num_Bank_Accounts
# 0.0                 1952    788      1677    4417
# 1.0                 2088    713      1739    4540
# 2.0                 2148    641      1551    4340
# 3.0                 2989   1892      7226   12107
# 4.0                 3014   1949      7380   12343
# 5.0                 2899   2003      7396   12298
# 6.0                  947   4725      7503   13175
# 7.0                  792   4851      7356   12999
# 8.0                  860   4714      7366   12940
# 9.0                   65   3465      1973    5503
# 10.0                  74   3251      2004    5329
# 11.0                   0      6         3       9
# All                17828  28998     53174  100000

# %% [markdown]
# # Q5==>credit_score based on no of credit_cards

# %%
a=pd.crosstab([df.Num_Credit_Card],[df.Credit_Score],margins=True)
a
# Out:
# Credit_Score      Good   Poor  Standard     All
# Num_Credit_Card
# 0.0                 11      0         3      14
# 1.0               1703      2       480    2185
# 2.0               1690     14       492    2196
# 3.0               3228   1882      8450   13560
# 4.0               3497   2017      8848   14362
# 5.0               3598   5335      9970   18903
# 6.0               1917   5132      9883   16932
# 7.0               1991   5310      9723   17024
# 8.0                 92   3187      1794    5073
# 9.0                 64   2973      1716    4753
# 10.0                37   3124      1801    4962
# 11.0                 0     22        14      36
# All              17828  28998     53174  100000

# %% [markdown]
# # Q6==>credit_score based on avarage interest rate

# %%
a=pd.crosstab([df.Interest_Rate],[df.Credit_Score],margins=True)
a
# Out:
# Credit_Score    Good   Poor  Standard     All
# Interest_Rate
# 1.0             1241    411      1092    2744
# 2.0             1227    390       903    2520
# 3.0             1317    444      1063    2824
# 4.0             1415    367       858    2640
# 5.0             1466    666      2964    5096
# 6.0             1307    519      3006    4832
# 7.0             1354    584      2646    4584
# 8.0             1539    717      2848    5104
# 9.0             1241    584      2751    4576
# 10.0            1184    612      2820    4616
# 11.0            1378    581      2553    4512
# 12.0            1455    443      2750    4648
# 13.0             169    136      2127    2432
# 14.0             135    185      1952    2272
# 15.0             238   1186      2648    4072
# 16.0             221   1261      2318    3800
# 17.0             151   1220      2517    3888
# 18.0             179   1402      2611    4192
# 19.0             185   1188      2331    3704
# ...

# %%
df.head(1)
# Out:
#      ID  Customer_ID  Month           Name   Age          SSN Occupation  \
# 0  5634         3392      1  Aaron Maashoh  23.0  821000265.0  Scientist
#
#    Annual_Income  Monthly_Inhand_Salary  Num_Bank_Accounts  ...  Credit_Mix  \
# 0       19114.12            1824.843333                3.0  ...        Good
#
#    Outstanding_Debt  Credit_Utilization_Ratio Credit_History_Age  \
# 0            809.98                  26.82262              265.0
#
#    Payment_of_Min_Amount  Total_EMI_per_month  Amount_invested_monthly  \
# 0                     No            49.574949                 21.46538
#
#                  Payment_Behaviour Monthly_Balance  Credit_Score
# 0  High_spent_Small_value_payments      312.494089          Good
#
# [1 rows x 28 columns]

# %% [markdown]
# # Q7==>credit_score based on no of loans taken by the person

# %%
a=pd.crosstab([df.Num_of_Loan],[df.Credit_Score],margins=True)
a
# Out:
# Credit_Score   Good   Poor  Standard     All
# Num_of_Loan
# 0.0            3444   1336      6628   11408
# 1.0            3170   1233      6725   11128
# 2.0            3441   3757      8514   15712
# 3.0            3602   3437      8713   15752
# 4.0            3473   3284      8699   15456
# 5.0             194   3891      3443    7528
# 6.0             189   4132      3823    8144
# 7.0             183   4025      3472    7680
# 8.0              63   1836      1437    3336
# 9.0              69   2067      1720    3856
# All           17828  28998     53174  100000

# %% [markdown]
# # Q8==> credit_score based on Avarage no of days delayed for credit card payment

# %%
a=pd.crosstab([df.Num_of_Delayed_Payment],[df.Credit_Score],margins=True)
a
# Out:
# Credit_Score             Good   Poor  Standard     All
# Num_of_Delayed_Payment
# 0.0                      1073    293       715    2081
# 1.0                       940    372       731    2043
# 2.0                       931    332       808    2071
# 3.0                       967    339       768    2074
# 4.0                       879    327       775    1981
# 5.0                      1023    374       866    2263
# 6.0                      1071    367      1053    2491
# 7.0                       992    374      1169    2535
# 8.0                      1303   1041      2956    5300
# 9.0                      1200   1128      3071    5399
# 10.0                     1316   1165      3321    5802
# 11.0                     1121   1037      3114    5272
# 12.0                     1127   1078      3288    5493
# 13.0                      507    962      2863    4332
# 14.0                      551   1034      2918    4503
# 15.0                      516   1792      3416    5724
# ...

# %% [markdown]
# # Q9==>credit_score based on outstanding debit

# %%
a=pd.crosstab([df.Outstanding_Debt],[df.Credit_Score],margins=True)
a
# Out:
# Credit_Score       Good   Poor  Standard     All
# Outstanding_Debt
# 0.23                  7      0         1       8
# 0.34                  0      0         8       8
# 0.54                  0      5         3       8
# 0.56                  0      1         7       8
# 0.77                  0      3         5       8
# ...                 ...    ...       ...     ...
# 4992.25               0      6         2       8
# 4997.05               0      6         2       8
# 4997.1                0      6         2       8
# 4998.07               5      0         3       8
# All               17828  28998     53174  100000
#
# [12204 rows x 4 columns]

# %% [markdown]
# # Q10==>credit_score based on credit utilization ratio

# %%
a=pd.crosstab([df.Credit_Utilization_Ratio],[df.Credit_Score],margins=True)
a
# Out:
# Credit_Score               Good   Poor  Standard     All
# Credit_Utilization_Ratio
# 20.0                          0      0         1       1
# 20.10076996070649             0      0         1       1
# 20.172941895510625            0      1         0       1
# 20.244130348792105            0      1         0       1
# 20.25707335904936             1      0         0       1
# ...                         ...    ...       ...     ...
# 49.25498297529708             0      0         1       1
# 49.52232429787243             1      0         0       1
# 49.56451934738699             0      0         1       1
# 50.00000000000001             0      0         1       1
# All                       17828  28998     53174  100000
#
# [100001 rows x 4 columns]

# %% [markdown]
# # Q11==>credit_score based on credit history age

# %%
a=pd.crosstab([df.Credit_History_Age],[df.Credit_Score],margins=True)
a
# Out:
# Credit_Score         Good   Poor  Standard     All
# Credit_History_Age
# 1.0                     0      1         1       2
# 2.0                     0      7         8      15
# 3.0                     0     12         9      21
# 4.0                     0     22        15      37
# 5.0                     0     22        22      44
# ...                   ...    ...       ...     ...
# 401.0                  32      9        56      97
# 402.0                  22      6        25      53
# 403.0                   4      2         9      15
# 404.0                   5      2         8      15
# All                 17828  28998     53174  100000
#
# [405 rows x 4 columns]

# %% [markdown]
# # Q12==>credit_score based on total no of EMI per month

# %%
a=pd.crosstab([df.Total_EMI_per_month],[df.Credit_Score],margins=True)
a
# Out:
# Credit_Score          Good   Poor  Standard     All
# Total_EMI_per_month
# 0.0                   3159   1318      6508   10985
# 4.4628374669131645       0      0         8       8
# 4.713183571733377        0      5         3       8
# 4.865689677072079        0      0         8       8
# 4.916138542370655        0      0         8       8
# ...                    ...    ...       ...     ...
# 1745.0                   0      1         0       1
# 1762.0                   0      0         1       1
# 1775.0                   0      0         1       1
# 1779.1032538262775       4      0         1       5
# All                  17828  28998     53174  100000
#
# [11891 rows x 4 columns]

# %% [markdown]
# # Q13==>credit_score based on Amount_invested_monthly

# %%
a=pd.crosstab([df.Amount_invested_monthly],[df.Credit_Score],margins=True)
a
# Out:
# Credit_Score              Good   Poor  Standard     All
# Amount_invested_monthly
# 0.0                        162    932       826    1920
# 10.004221751836038           0      0         8       8
# 10.010194262612965           0      0         8       8
# 10.011424795004292           0      8         0       8
# 10.02534445774556            0      7         1       8
# ...                        ...    ...       ...     ...
# 327.0133343382988            0      3         5       8
# 330.618021115136             0      6         2       8
# 356.55036144099404           7      0         1       8
# 434.1910893520318            0      0         8       8
# All                      17828  28998     53174  100000
#
# [12262 rows x 4 columns]

# %% [markdown]
# # Q14==>credit_score based on Monthly_Balance

# %%
a=pd.crosstab([df.Monthly_Balance],[df.Credit_Score],margins=True)
a
# Out:
# Credit_Score         Good   Poor  Standard     All
# Monthly_Balance
# 0.0077596647753352      1      0         0       1
# 0.0886278653490535      0      1         0       1
# 0.0954824960197697      0      1         0       1
# 0.103402231183395       0      0         1       1
# 0.1311356510956329      0      0         1       1
# ...                   ...    ...       ...     ...
# 1183.2267785083748      0      0         1       1
# 1183.3707601946096      0      0         1       1
# 1183.625103845107       1      0         0       1
# 1183.9306960885192      2      0         6       8
# All                 17828  28998     53174  100000
#
# [98495 rows x 4 columns]
